# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import sqrt, pi
print(sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %%
## No module numpy
## pip install numpy or requirements.txt
import numpy as np ## np is alias
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
sqrt(16)
# Out:
# 4.0

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(4,5)
# Out:
# 9
