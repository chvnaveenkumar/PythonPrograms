# %%
## Module Expression
a=2
b=5
add_result = a+b
print(add_result)
# Out:
# 7

# %%
21/5
# Out:
# 4.2

# %%
21//5 ## Floor whatever is the low value it will come out
# Out:
# 4

# %%
##Comparison operator   
a=10
b=10
a==b
# Out:
# True

# %%
str1="Krish"
str2="Krish"

str1==str2
str1!=str2
# Out:
# False

# %%
str3="Krish"
str4="krish"
str3==str4
# Out:
# False

# %%
# NOt operator
X=True
not X
# Out:
# False
