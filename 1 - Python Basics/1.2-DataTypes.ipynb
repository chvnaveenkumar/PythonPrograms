# %%
## Integer Example
age = 35
type(age)
# Out:
# int

# %%
## Floating Example
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## String Example
name="Krish"
print(name)
print(name, type(name))
# Out:
# Krish
# Krish <class 'str'>

# %%
## Boolean Example
is_True = True
type(is_True)
# Out:
# bool

# %%
is_true=bool() ## By default False
print(is_true)

a=10
b=10
a==b
type(a==b)
# Out:
# False
# bool

# %%
## Common errors
result=="Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ## Common errors
# ----> 2 result=="Hello" + 5
#
# NameError: name 'result' is not defined
