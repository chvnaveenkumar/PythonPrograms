# %%
## Exception handling allows you to handle errors and take corrective actions without stopping

## Execeptin are events that distrub the normal flow of program.

# %%
a=10
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a=10
# ----> 2 a=b
#       4 ## Exception try, except block
#       5 try:
#
# NameError: name 'b' is not defined

# %%
## Exception try, except block
try:
    a=b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
## Exception try, except block
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result= 1/0
except ZeroDivisionError as zde:
    print(zde)
# Out:
# division by zero

# %%
try:
    result= 1/2
    a=b
except ZeroDivisionError as zde:
    print(zde)

## because it is not handled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 try:
#       2     result= 1/2
# ----> 3     a=b
#       4 except ZeroDivisionError as zde:
#       5     print(zde)
#
# NameError: name 'b' is not defined

# %%
try:
    result= 1/0
except ZeroDivisionError as zde:
    print(zde)
except Exception as ex:
    print(ex)
# Out:
# division by zero

# %%
try:
    num=input("Enter a number")
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter demoninator greater than 0")
except Exception as ex:
    print(ex)
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %%
## try, except, else block 
## If no exception then it will execute else block

try:
    num= int(input("Enter a number:"))
    restult = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter demoninator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The resule is {result}")
# Out:
# The resule is 0.5

# %%
## try, except, else block, finally

try:
    num= int(input("Enter a number:"))
    restult = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter demoninator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The resule is {result}")
finally:
    print("Finally block")
# Out:
# Enter demoninator greater than 0
# Finally block

# %%
## File handling and Exception Handling

try:
    file=open('example1.txt', 'r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("This file does not exists")
finally:
    if 'file' in locals() or not file.closed():
        file.close()
