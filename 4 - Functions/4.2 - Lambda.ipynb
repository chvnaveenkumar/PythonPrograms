# %%
lambda arguments: expression

# %%
def addition(a,b):
    return a+b

addition(2,5)

# %%
addition = lambda a,b:a+b
print(addition(2,3))
print(type(addition))
# Out:
# 5
# <class 'function'>

# %%
even = lambda num: num % 2 == 0 
print(12)
# Out:
# 12

# %%
addition = lambda x,y,z: x+y+z
print(addition(2,3,4))
# Out:
# 9

# %%
## map() - It applies function to all items in a list

numbers = [1,2,3,4,5]
squared_numbers = lambda x: x**2
print(squared_numbers(numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 numbers = [1,2,3,4,5]
#       4 squared_numbers = lambda x: x**2
# ----> 5 print(squared_numbers(numbers))
#
# Cell In[7], line 4, in <lambda>(x)
#       1 ## map()
#       3 numbers = [1,2,3,4,5]
# ----> 4 squared_numbers = lambda x: x**2
#       5 print(squared_numbers(numbers))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
